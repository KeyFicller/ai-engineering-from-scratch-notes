# %% [markdown]
# ## Sampling

# %% [markdown]
# ### Why Sampling Matters
#
# * **Generation**. Top-k, Temperature
# * **Train**. Dropout, Dataset
# * **Estimation**
# * **Exploration**
#
# **You can only sample directly from simple distributions (uniform, noraml), for everything else, you need a method to convert simple samples into samples from your target distribution**

# %% [markdown]
# ### Unifrom Random Sampling
#
# `U ~ Unifrom (0, 1)`
