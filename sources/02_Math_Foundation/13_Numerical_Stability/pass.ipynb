# %%
pass

# %% [markdown]
# ## Float Comparsion

# %%
import math

# This return False
print(0.1 + 0.2 == 0.3)

#
print(abs(0.1 + 0.2 - 0.3) < 1e-6)
print(math.isclose(0.1 + 0.2, 0.3))
# Out:
# False
