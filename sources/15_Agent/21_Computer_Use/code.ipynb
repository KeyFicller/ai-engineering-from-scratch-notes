# %% [markdown]
# # 使用电脑： Claude、OpenAI CUA、Gemini
#
# 2026年有三个生产使用电脑模型。都是基于视觉的，也都把截图、DOM文本和工具输出当做不可信输入。只有用户直接的指令才被视为许可。逐步安全服务是常态。
#
# ## 基本概念
#
# |模型|组成/原理|备注|
# |---|---|---|
# |Claude Computer use|截图进、键鼠命令出||
# |OpenAI CUA/Operator|GUI交互强化学习||
# |Gemini 2.5 Computer use|仅浏览器的13个操作||
